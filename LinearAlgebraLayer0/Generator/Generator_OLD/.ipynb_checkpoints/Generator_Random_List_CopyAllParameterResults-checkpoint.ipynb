# %%
#Generate one time and copy to RandomIndices

# %%
# import random

# NoOfRresults = 2003904
# NoOfRandomResults = 100
# if NoOfRandomResults >= NoOfRresults:
#     RandomIndices = range(NoOfRresults)
# else:
#     RandomIndices = random.sample(range(NoOfRresults),NoOfRandomResults)
# RandomIndices

# %%
RandomIndices = [1162250,
 90962,
 115642,
 881624,
 1584132,
 588226,
 1066452,
 1335590,
 1284561,
 370169,
 815933,
 868818,
 404162,
 1563008,
 1282166,
 1093850,
 1438319,
 1043379,
 555238,
 1100447,
 641117,
 1254834,
 1657458,
 120445,
 491253,
 1959430,
 671553,
 311213,
 487029,
 629950,
 40679,
 266054,
 1913666,
 1402930,
 1348706,
 1147597,
 709453,
 1296479,
 1264685,
 1595064,
 1625283,
 718204,
 1894716,
 472495,
 1891357,
 1634776,
 24250,
 1111363,
 1214442,
 237660,
 1521687,
 1430994,
 1573271,
 888470,
 1496068,
 90052,
 1701042,
 1830137,
 1521626,
 292406,
 1985703,
 614104,
 713102,
 1896731,
 318153,
 1274730,
 193302,
 151705,
 921979,
 601861,
 361397,
 1836389,
 1474692,
 1994137,
 1168015,
 1932860,
 230819,
 522023,
 1660463,
 69336,
 1993605,
 1609732,
 994895,
 1617240,
 1366244,
 1696286,
 1195221,
 904700,
 838603,
 968240,
 1677903,
 833345,
 459772,
 1750018,
 1651696,
 181987,
 1395202,
 1305415,
 1835849,
 743791]
RandomIndices
# Out:
# [1162250,
#  90962,
#  115642,
#  881624,
#  1584132,
#  588226,
#  1066452,
#  1335590,
#  1284561,
#  370169,
#  815933,
#  868818,
#  404162,
#  1563008,
#  1282166,
#  1093850,
#  1438319,
#  1043379,
#  555238,
#  1100447,
#  641117,
#  1254834,
#  1657458,
#  120445,
#  491253,
#  1959430,
#  671553,
#  311213,
#  487029,
#  629950,
#  40679,
#  266054,
#  1913666,
#  1402930,
#  1348706,
#  1147597,
#  709453,
#  1296479,
#  1264685,
#  1595064,
#  1625283,
#  718204,
#  1894716,
#  472495,
#  1891357,
#  1634776,
#  24250,
#  1111363,
#  1214442,
#  237660,
#  1521687,
#  1430994,
#  1573271,
#  888470,
#  1496068,
#  90052,
#  1701042,
#  1830137,
#  1521626,
#  292406,
#  1985703,
#  614104,
#  713102,
#  1896731,
#  318153,
#  1274730,
#  193302,
#  151705,
#  921979,
#  601861,
#  361397,
#  1836389,
#  1474692,
#  1994137,
#  1168015,
#  1932860,
#  230819,
#  522023,
#  1660463,
#  69336,
#  1993605,
#  1609732,
#  994895,
#  1617240,
#  1366244,
#  1696286,
# ...
